# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from collections import OrderedDict
import PIL
from PIL import Image
import numpy as np
import seaborn as sb
# Out:
# C:\Users\Mostafa\anaconda3\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'C:\Users\Mostafa\anaconda3\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
training_transforms = transforms.Compose([transforms.RandomRotation(30),
                                     transforms.RandomResizedCrop(224),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])
testing_transforms= transforms.Compose([transforms.Resize(255),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
training_datasets = datasets.ImageFolder(train_dir, transform=training_transforms)
validation_datasets = datasets.ImageFolder(valid_dir, transform=testing_transforms)
testing_datasets= datasets.ImageFolder(test_dir, transform=testing_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
training_dataloaders = torch.utils.data.DataLoader(training_datasets, batch_size=64, shuffle=True)
validation_dataloaders=torch.utils.data.DataLoader(validation_datasets, batch_size=64)
testing_dataloaders= torch.utils.data.DataLoader(testing_datasets, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = models.vgg16(pretrained=True)

# %%
model
for param in model.parameters():
    param.requires_grad=False
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 5024)),
                          ('relu1', nn.ReLU()),
                          ('drop1',nn.Dropout(0.3)),
                          ('fc2', nn.Linear(5024, 1024)),
                          ('relu2',nn.ReLU()),
                          ('drop2',nn.Dropout(0.3)),
                          ('fc3', nn.Linear(1024, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
model.classifier = classifier
model.to(device)
optimizer=optim.Adam(model.classifier.parameters(), lr=0.001)
criterion= nn.NLLLoss()

# %%
epochs=6
steps=0
running_loss=0
print_every= 5
for epoch in range(epochs):
    for inputs, labels in training_dataloaders:
        steps+=1
        # Move input and label tensors to the default device
        #print(str(device))
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
        inputs, labels= inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        #training
        logps= model.forward(inputs)
        loss= criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss+= loss.item()
        if steps % print_every == 0:
            validation_loss= 0
            accuracy=0
            model.eval()
            with torch.no_grad():
                for inputs, labels in validation_dataloaders:
                    torch.set_default_tensor_type('torch.cuda.FloatTensor')
                    inputs, labels= inputs.to(device), labels.to(device)
                    logps= model.forward(inputs)
                    batch_loss= criterion(logps, labels)
                    validation_loss+=batch_loss.item()
                    # Calculate accuracy
                    ps= torch.exp(logps)
                    top_p, top_class= ps.topk(1, dim=1)
                    equals= top_class== labels.view(*top_class.shape)
                    accuracy+= torch.mean(equals.type(torch.FloatTensor)).item()
            print("Step number {}".format(steps))
            print("Epoch number {}/{}".format(epoch+1, epochs))
            print("Training Loss is {:.3f}".format(running_loss/print_every))
            print("Validation Loss is {:.3f}".format(validation_loss/len(validation_dataloaders)))
            print("Validation accuracy  is {:.3f}".format(accuracy/len(validation_dataloaders)))
            running_loss=0
            torch.set_default_tensor_type('torch.FloatTensor')
            print("*********")
            model.train()
print("finished==============")
# Out:
# Step number 5
# Epoch number 1/6
# Training Loss is 7.089
# Validation Loss is 5.257
# Validation accuracy  is 0.034
# *********
# Step number 10
# Epoch number 1/6
# Training Loss is 4.925
# Validation Loss is 4.512
# Validation accuracy  is 0.060
# *********
# Step number 15
# Epoch number 1/6
# Training Loss is 4.481
# Validation Loss is 4.296
# Validation accuracy  is 0.066
# *********
# Step number 20
# Epoch number 1/6
# Training Loss is 4.335
# Validation Loss is 4.054
# Validation accuracy  is 0.150
# *********
# Step number 25
# Epoch number 1/6
# Training Loss is 4.232
# Validation Loss is 3.802
# Validation accuracy  is 0.161
# *********
# Step number 30
# Epoch number 1/6
# Training Loss is 4.108
# Validation Loss is 3.506
# Validation accuracy  is 0.231
# *********
# Step number 35
# Epoch number 1/6
# Training Loss is 3.745
# Validation Loss is 3.265
# Validation accuracy  is 0.233
# *********
# Step number 40
# Epoch number 1/6
# Training Loss is 3.556
# Validation Loss is 2.920
# Validation accuracy  is 0.341
# *********
# Step number 45
# Epoch number 1/6
# Training Loss is 3.227
# Validation Loss is 2.547
# Validation accuracy  is 0.388
# *********
# Step number 50
# Epoch number 1/6
# Training Loss is 3.044
# Validation Loss is 2.440
# Validation accuracy  is 0.409
# *********
# Step number 55
# Epoch number 1/6
# Training Loss is 2.792
# Validation Loss is 2.192
# Validation accuracy  is 0.474
# *********
# Step number 60
# Epoch number 1/6
# Training Loss is 2.786
# Validation Loss is 2.009
# Validation accuracy  is 0.486
# *********
# Step number 65
# Epoch number 1/6
# Training Loss is 2.475
# Validation Loss is 1.989
# Validation accuracy  is 0.475
# *********
# Step number 70
# Epoch number 1/6
# Training Loss is 2.239
# Validation Loss is 1.720
# Validation accuracy  is 0.567
# *********
# Step number 75
# Epoch number 1/6
# Training Loss is 2.228
# Validation Loss is 1.754
# Validation accuracy  is 0.530
# *********
# Step number 80
# Epoch number 1/6
# Training Loss is 2.238
# Validation Loss is 1.522
# Validation accuracy  is 0.619
# *********
# Step number 85
# Epoch number 1/6
# Training Loss is 2.102
# Validation Loss is 1.413
# Validation accuracy  is 0.626
# *********
# Step number 90
# Epoch number 1/6
# Training Loss is 1.950
# Validation Loss is 1.329
# Validation accuracy  is 0.622
# *********
# Step number 95
# Epoch number 1/6
# Training Loss is 2.050
# Validation Loss is 1.333
# Validation accuracy  is 0.627
# *********
# Step number 100
# Epoch number 1/6
# Training Loss is 1.933
# Validation Loss is 1.221
# Validation accuracy  is 0.663
# *********
# Step number 105
# Epoch number 2/6
# Training Loss is 1.714
# Validation Loss is 1.291
# Validation accuracy  is 0.633
# *********
# Step number 110
# Epoch number 2/6
# Training Loss is 2.054
# Validation Loss is 1.203
# Validation accuracy  is 0.651
# *********
# Step number 115
# Epoch number 2/6
# Training Loss is 1.772
# Validation Loss is 1.203
# Validation accuracy  is 0.650
# *********
# Step number 120
# Epoch number 2/6
# Training Loss is 1.617
# Validation Loss is 1.075
# Validation accuracy  is 0.693
# *********
# Step number 125
# Epoch number 2/6
# Training Loss is 1.585
# Validation Loss is 1.046
# Validation accuracy  is 0.710
# *********
# Step number 130
# Epoch number 2/6
# Training Loss is 1.494
# Validation Loss is 1.208
# Validation accuracy  is 0.670
# *********
# Step number 135
# Epoch number 2/6
# Training Loss is 1.635
# Validation Loss is 1.119
# Validation accuracy  is 0.690
# *********
# Step number 140
# Epoch number 2/6
# Training Loss is 1.650
# Validation Loss is 1.031
# Validation accuracy  is 0.724
# *********
# Step number 145
# Epoch number 2/6
# Training Loss is 1.675
# Validation Loss is 1.017
# Validation accuracy  is 0.725
# *********
# Step number 150
# Epoch number 2/6
# Training Loss is 1.746
# Validation Loss is 1.018
# Validation accuracy  is 0.714
# *********
# Step number 155
# Epoch number 2/6
# Training Loss is 1.615
# Validation Loss is 0.931
# Validation accuracy  is 0.722
# *********
# Step number 160
# Epoch number 2/6
# Training Loss is 1.378
# Validation Loss is 0.908
# Validation accuracy  is 0.732
# *********
# Step number 165
# Epoch number 2/6
# Training Loss is 1.538
# Validation Loss is 0.853
# Validation accuracy  is 0.755
# *********
# Step number 170
# Epoch number 2/6
# Training Loss is 1.483
# Validation Loss is 0.912
# Validation accuracy  is 0.738
# *********
# Step number 175
# Epoch number 2/6
# Training Loss is 1.473
# Validation Loss is 0.880
# Validation accuracy  is 0.742
# *********
# Step number 180
# Epoch number 2/6
# Training Loss is 1.535
# Validation Loss is 0.859
# Validation accuracy  is 0.757
# *********
# Step number 185
# Epoch number 2/6
# Training Loss is 1.527
# Validation Loss is 0.914
# Validation accuracy  is 0.733
# *********
# Step number 190
# Epoch number 2/6
# Training Loss is 1.395
# Validation Loss is 0.799
# Validation accuracy  is 0.781
# *********
# Step number 195
# Epoch number 2/6
# Training Loss is 1.441
# Validation Loss is 0.775
# Validation accuracy  is 0.769
# *********
# Step number 200
# Epoch number 2/6
# Training Loss is 1.420
# Validation Loss is 0.715
# Validation accuracy  is 0.794
# *********
# Step number 205
# Epoch number 2/6
# Training Loss is 1.288
# Validation Loss is 0.711
# Validation accuracy  is 0.799
# *********
# Step number 210
# Epoch number 3/6
# Training Loss is 1.424
# Validation Loss is 0.819
# Validation accuracy  is 0.764
# *********
# Step number 215
# Epoch number 3/6
# Training Loss is 1.110
# Validation Loss is 0.801
# Validation accuracy  is 0.779
# *********
# Step number 220
# Epoch number 3/6
# Training Loss is 1.307
# Validation Loss is 0.717
# Validation accuracy  is 0.806
# *********
# Step number 225
# Epoch number 3/6
# Training Loss is 1.370
# Validation Loss is 0.795
# Validation accuracy  is 0.786
# *********
# Step number 230
# Epoch number 3/6
# Training Loss is 1.319
# Validation Loss is 0.795
# Validation accuracy  is 0.775
# *********
# Step number 235
# Epoch number 3/6
# Training Loss is 1.253
# Validation Loss is 0.706
# Validation accuracy  is 0.803
# *********
# Step number 240
# Epoch number 3/6
# Training Loss is 1.248
# Validation Loss is 0.691
# Validation accuracy  is 0.794
# *********
# Step number 245
# Epoch number 3/6
# Training Loss is 1.211
# Validation Loss is 0.668
# Validation accuracy  is 0.806
# *********
# Step number 250
# Epoch number 3/6
# Training Loss is 1.213
# Validation Loss is 0.801
# Validation accuracy  is 0.779
# *********
# Step number 255
# Epoch number 3/6
# Training Loss is 1.463
# Validation Loss is 0.702
# Validation accuracy  is 0.803
# *********
# Step number 260
# Epoch number 3/6
# Training Loss is 1.321
# Validation Loss is 0.617
# Validation accuracy  is 0.836
# *********
# Step number 265
# Epoch number 3/6
# Training Loss is 1.293
# Validation Loss is 0.622
# Validation accuracy  is 0.821
# *********
# Step number 270
# Epoch number 3/6
# Training Loss is 1.178
# Validation Loss is 0.641
# Validation accuracy  is 0.818
# *********
# Step number 275
# Epoch number 3/6
# Training Loss is 1.225
# Validation Loss is 0.606
# Validation accuracy  is 0.833
# *********
# Step number 280
# Epoch number 3/6
# Training Loss is 1.172
# Validation Loss is 0.589
# Validation accuracy  is 0.839
# *********
# Step number 285
# Epoch number 3/6
# Training Loss is 1.232
# Validation Loss is 0.582
# Validation accuracy  is 0.835
# *********
# Step number 290
# Epoch number 3/6
# Training Loss is 1.166
# Validation Loss is 0.573
# Validation accuracy  is 0.822
# *********
# Step number 295
# Epoch number 3/6
# Training Loss is 1.260
# Validation Loss is 0.526
# Validation accuracy  is 0.857
# *********
# Step number 300
# Epoch number 3/6
# Training Loss is 1.297
# Validation Loss is 0.551
# Validation accuracy  is 0.841
# *********
# Step number 305
# Epoch number 3/6
# Training Loss is 1.322
# Validation Loss is 0.561
# Validation accuracy  is 0.845
# *********
# Step number 310
# Epoch number 4/6
# Training Loss is 1.193
# Validation Loss is 0.582
# Validation accuracy  is 0.841
# *********
# Step number 315
# Epoch number 4/6
# Training Loss is 1.064
# Validation Loss is 0.644
# Validation accuracy  is 0.820
# *********
# Step number 320
# Epoch number 4/6
# Training Loss is 1.082
# Validation Loss is 0.648
# Validation accuracy  is 0.804
# *********
# Step number 325
# Epoch number 4/6
# Training Loss is 1.167
# Validation Loss is 0.583
# Validation accuracy  is 0.831
# *********
# Step number 330
# Epoch number 4/6
# Training Loss is 1.228
# Validation Loss is 0.492
# Validation accuracy  is 0.866
# *********
# Step number 335
# Epoch number 4/6
# Training Loss is 1.211
# Validation Loss is 0.529
# Validation accuracy  is 0.841
# *********
# Step number 340
# Epoch number 4/6
# Training Loss is 0.908
# Validation Loss is 0.529
# Validation accuracy  is 0.855
# *********
# Step number 345
# Epoch number 4/6
# Training Loss is 1.070
# Validation Loss is 0.578
# Validation accuracy  is 0.841
# *********
# Step number 350
# Epoch number 4/6
# Training Loss is 1.000
# Validation Loss is 0.552
# Validation accuracy  is 0.857
# *********
# Step number 355
# Epoch number 4/6
# Training Loss is 1.190
# Validation Loss is 0.559
# Validation accuracy  is 0.839
# *********
# Step number 360
# Epoch number 4/6
# Training Loss is 1.090
# Validation Loss is 0.549
# Validation accuracy  is 0.842
# *********
# Step number 365
# Epoch number 4/6
# Training Loss is 1.172
# Validation Loss is 0.504
# Validation accuracy  is 0.852
# *********
# Step number 370
# Epoch number 4/6
# Training Loss is 1.156
# Validation Loss is 0.514
# Validation accuracy  is 0.847
# *********
# Step number 375
# Epoch number 4/6
# Training Loss is 1.095
# Validation Loss is 0.486
# Validation accuracy  is 0.855
# *********
# Step number 380
# Epoch number 4/6
# Training Loss is 0.948
# Validation Loss is 0.502
# Validation accuracy  is 0.857
# *********
# Step number 385
# Epoch number 4/6
# Training Loss is 1.123
# Validation Loss is 0.572
# Validation accuracy  is 0.836
# *********
# Step number 390
# Epoch number 4/6
# Training Loss is 0.995
# Validation Loss is 0.526
# Validation accuracy  is 0.859
# *********
# Step number 395
# Epoch number 4/6
# Training Loss is 1.001
# Validation Loss is 0.510
# Validation accuracy  is 0.859
# *********
# Step number 405
# Epoch number 4/6
# Training Loss is 1.030
# Validation Loss is 0.601
# Validation accuracy  is 0.829
# *********
# Step number 410
# Epoch number 4/6
# Training Loss is 1.270
# Validation Loss is 0.583
# Validation accuracy  is 0.839
# *********
# Step number 415
# Epoch number 5/6
# Training Loss is 1.114
# Validation Loss is 0.599
# Validation accuracy  is 0.825
# *********
# Step number 420
# Epoch number 5/6
# Training Loss is 1.067
# Validation Loss is 0.548
# Validation accuracy  is 0.853
# *********
# Step number 425
# Epoch number 5/6
# Training Loss is 1.095
# Validation Loss is 0.478
# Validation accuracy  is 0.886
# *********
# Step number 430
# Epoch number 5/6
# Training Loss is 0.956
# Validation Loss is 0.497
# Validation accuracy  is 0.859
# *********
# Step number 435
# Epoch number 5/6
# Training Loss is 1.073
# Validation Loss is 0.503
# Validation accuracy  is 0.858
# *********
# Step number 440
# Epoch number 5/6
# Training Loss is 0.946
# Validation Loss is 0.482
# Validation accuracy  is 0.858
# *********
# Step number 445
# Epoch number 5/6
# Training Loss is 0.857
# Validation Loss is 0.482
# Validation accuracy  is 0.868
# *********
# Step number 450
# Epoch number 5/6
# Training Loss is 1.009
# Validation Loss is 0.487
# Validation accuracy  is 0.866
# *********
# Step number 455
# Epoch number 5/6
# Training Loss is 0.889
# Validation Loss is 0.503
# Validation accuracy  is 0.858
# *********
# Step number 460
# Epoch number 5/6
# Training Loss is 1.082
# Validation Loss is 0.496
# Validation accuracy  is 0.867
# *********
# Step number 465
# Epoch number 5/6
# Training Loss is 0.998
# Validation Loss is 0.518
# Validation accuracy  is 0.863
# *********
# Step number 470
# Epoch number 5/6
# Training Loss is 1.084
# Validation Loss is 0.561
# Validation accuracy  is 0.838
# *********
# Step number 475
# Epoch number 5/6
# Training Loss is 1.025
# Validation Loss is 0.546
# Validation accuracy  is 0.848
# *********
# Step number 480
# Epoch number 5/6
# Training Loss is 1.111
# Validation Loss is 0.519
# Validation accuracy  is 0.853
# *********
# Step number 485
# Epoch number 5/6
# Training Loss is 1.051
# Validation Loss is 0.499
# Validation accuracy  is 0.856
# *********
# Step number 490
# Epoch number 5/6
# Training Loss is 1.144
# Validation Loss is 0.484
# Validation accuracy  is 0.870
# *********
# Step number 495
# Epoch number 5/6
# Training Loss is 0.849
# Validation Loss is 0.525
# Validation accuracy  is 0.857
# *********
# Step number 500
# Epoch number 5/6
# Training Loss is 1.022
# Validation Loss is 0.508
# Validation accuracy  is 0.867
# *********
# Step number 505
# Epoch number 5/6
# Training Loss is 1.196
# Validation Loss is 0.485
# Validation accuracy  is 0.863
# *********
# Step number 510
# Epoch number 5/6
# Training Loss is 1.137
# Validation Loss is 0.509
# Validation accuracy  is 0.869
# *********
# Step number 515
# Epoch number 5/6
# Training Loss is 0.932
# Validation Loss is 0.438
# Validation accuracy  is 0.876
# *********
# Step number 520
# Epoch number 6/6
# Training Loss is 1.051
# Validation Loss is 0.446
# Validation accuracy  is 0.865
# *********
# Step number 525
# Epoch number 6/6
# Training Loss is 0.938
# Validation Loss is 0.441
# Validation accuracy  is 0.880
# *********
# Step number 530
# Epoch number 6/6
# Training Loss is 0.939
# Validation Loss is 0.465
# Validation accuracy  is 0.878
# *********
# Step number 535
# Epoch number 6/6
# Training Loss is 1.098
# Validation Loss is 0.485
# Validation accuracy  is 0.866
# *********
# Step number 540
# Epoch number 6/6
# Training Loss is 0.806
# Validation Loss is 0.495
# Validation accuracy  is 0.858
# *********
# Step number 545
# Epoch number 6/6
# Training Loss is 1.114
# Validation Loss is 0.489
# Validation accuracy  is 0.861
# *********
# Step number 550
# Epoch number 6/6
# Training Loss is 1.021
# Validation Loss is 0.442
# Validation accuracy  is 0.880
# *********
# Step number 555
# Epoch number 6/6
# Training Loss is 0.981
# Validation Loss is 0.446
# Validation accuracy  is 0.881
# *********
# Step number 560
# Epoch number 6/6
# Training Loss is 1.018
# Validation Loss is 0.474
# Validation accuracy  is 0.873
# *********
# Step number 565
# Epoch number 6/6
# Training Loss is 1.049
# Validation Loss is 0.443
# Validation accuracy  is 0.892
# *********
# Step number 570
# Epoch number 6/6
# Training Loss is 0.903
# Validation Loss is 0.500
# Validation accuracy  is 0.865
# *********
# Step number 575
# Epoch number 6/6
# Training Loss is 0.812
# Validation Loss is 0.465
# Validation accuracy  is 0.870
# *********
# Step number 580
# Epoch number 6/6
# Training Loss is 0.967
# Validation Loss is 0.470
# Validation accuracy  is 0.875
# *********
# Step number 585
# Epoch number 6/6
# Training Loss is 1.134
# Validation Loss is 0.446
# Validation accuracy  is 0.876
# *********
# Step number 590
# Epoch number 6/6
# Training Loss is 1.039
# Validation Loss is 0.470
# Validation accuracy  is 0.861
# *********
# Step number 595
# Epoch number 6/6
# Training Loss is 0.977
# Validation Loss is 0.480
# Validation accuracy  is 0.864
# *********
# Step number 600
# Epoch number 6/6
# Training Loss is 0.884
# Validation Loss is 0.480
# Validation accuracy  is 0.882
# *********
# Step number 605
# Epoch number 6/6
# Training Loss is 0.999
# Validation Loss is 0.510
# Validation accuracy  is 0.871
# *********
# Step number 610
# Epoch number 6/6
# Training Loss is 1.097
# Validation Loss is 0.521
# Validation accuracy  is 0.861
# *********
# Step number 615
# Epoch number 6/6
# Training Loss is 0.949
# Validation Loss is 0.493
# Validation accuracy  is 0.875
# *********
# finished==============

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
testing_loss= 0
accuracy=0
counter=0
model.eval()
with torch.no_grad():
    for inputs, labels in testing_dataloaders:
       
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
        inputs, labels= inputs.to(device), labels.to(device)
        logps= model.forward(inputs)
        batch_loss= criterion(logps, labels)
        testing_loss+=batch_loss.item()
        # Calculate accuracy
        ps= torch.exp(logps)
        top_p, top_class= ps.topk(1, dim=1)
        equals= top_class== labels.view(*top_class.shape)
        accuracy+= torch.mean(equals.type(torch.FloatTensor)).item()
        print("batch number {}".format(counter))
        counter+=1
    print("testing Loss is {:.3f}".format(testing_loss/len(testing_dataloaders)))
    print("accuracy  is {:.3f}".format(accuracy/len(testing_dataloaders)))
    print("====================")
    torch.set_default_tensor_type('torch.FloatTensor')
print("Finished !! #############################")
# Out:
# batch number 0
# batch number 1
# batch number 2
# batch number 3
# batch number 4
# batch number 5
# batch number 6
# batch number 7
# batch number 8
# batch number 9
# batch number 10
# batch number 11
# batch number 12
# testing Loss is 0.572
# accuracy  is 0.852
# ====================
# Finished !! #############################

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
checkpoint={
    'epochs': epochs,
    'optimizer': optimizer.state_dict,
    'arch': 'vgg16',
   # 'classifier': model.classifier,
    'state_dict': model.state_dict(),
    'optimizer_dict': optimizer.state_dict(),
    'class_to_idx': training_datasets.class_to_idx
}
torch.save(checkpoint, 'trained_model_002.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    if torch.cuda.is_available():
        map_location=lambda storage, loc: storage.cuda()
    else:
        map_location='cpu'

#chkpoint = torch.load(checkpoint_path, map_location=map_location)
    checkpoint = torch.load(filepath, map_location=map_location)
    #model = models.resnet152(pretrained=True)
    model=  models.vgg16(pretrained=True)
    #model.arch = checkpoint['arch']
    model.class_to_idx = checkpoint['class_to_idx']
    model.classifier = classifier #checkpoint['classifier'] #newClassifier
    model.load_state_dict(checkpoint['state_dict'], strict=False)
    optimizer.load_state_dict(checkpoint['optimizer_dict'])
    model.class_to_idx = checkpoint['class_to_idx']
    
    
    for param in model.parameters():
        param.requires_grad = False
        
    return model
model=load_checkpoint('trained_model_002.pth')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=5024, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.3, inplace=False)
#     (fc2): Linear(in_features=5024, out_features=1024, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.3, inplace=False)
#     (fc3): Linear(in_features=1024, out_features=102, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=5024, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.3, inplace=False)
#     (fc2): Linear(in_features=5024, out_features=1024, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.3, inplace=False)
#     (fc3): Linear(in_features=1024, out_features=102, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %%
from PIL import Image 
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    pil_image=Image.open(image)
    #pil_image= pil_image/255
    img_transforms= transforms.Compose([transforms.Resize((256, 256)),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])
    transformed_img= img_transforms(pil_image)
   
    return  transformed_img #.numpy().transpose((2,0,1)).ToTensor()

img_1=process_image("image_03830.jpg")
    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax
imshow(process_image("image_03830.jpg"))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    img_tensor=(process_image(image_path))
    img_tensor.unsqueeze_(0)
    if torch.cuda.is_available():
        img_tensor= img_tensor.cuda()
        model= model.cuda()
   
    
    #print("*** "+ str(img.shape))
    print("#################")
    print((img_tensor.shape))
    #print(device)
    #img=img.to(device)
    #model=model.to(device)
    model.eval()
    with torch.no_grad():
        #torch.set_default_tensor_type('torch.cuda.FloatTensor')
        #logps= model.forward(img)
        #ps= torch.exp(logps)
        #print(ps)
        #top_p, top_class= ps.topk(topk)
        #top_class.unsqueeze_(0)
        #top_class= top_class.resize(topk)
        #top_p=top_p.resize(topk) 
        #print("dim is " +str(top_class.shape))
        #top_labels, top_props=[],[]
        output= model.forward(img_tensor)
        ps= torch.exp(output).data
        ps =ps.cpu()
        ps_topk=ps.topk(topk,dim=1)[0].numpy()[0]
        ps_topk_idx= ps.topk(topk)[1].numpy()[0]
        print("^^^^^^^^^^^^^^^^^ " )
        print(ps_topk)
        print("^^^^^^^^^^^^^^^^^ ")
        print(ps_topk_idx)
        #for c in top_class:
            #v=cat_to_name[str(c.item())]
          #  print(str(c.item()))
         #   top_labels.append(str(c.item()))
            #print(v)
        #top_labels = np.array(top_class.detach())[0]
        #print(top_p)
        #print(top_class)
        #for p in top_p:
         #   prob= p.item()
          #  top_props.append(prob)
        idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
        top_labels = [idx_to_class[idx] for idx in ps_topk_idx]
        top_flowers = [cat_to_name[lab] for lab in top_labels]

        return ps_topk, top_labels, top_flowers
       
predict('image_03830.jpg', model)
# Out:
# #################
# torch.Size([1, 3, 224, 224])
# ^^^^^^^^^^^^^^^^^
# [1.0000000e+00 4.5455204e-09 4.2440387e-10 1.7507028e-10 1.6706947e-10]
# ^^^^^^^^^^^^^^^^^
# [11 77 50 80 13]
# (array([1.0000000e+00, 4.5455204e-09, 4.2440387e-10, 1.7507028e-10,
#         1.6706947e-10], dtype=float32),
#  ['17', '77', '52', '8', '19'],
#  ['purple coneflower',
#   'passion flower',
#   'wild pansy',
#   'bird of paradise',
#   'balloon flower'])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %%
img_path='image_06657.jpg'
# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
img_title='poinsettia'

img = process_image(img_path)
imshow(img, ax, title = img_title)

#try to predict
probs, labels, flowers = predict(img_path, model) 
plt.subplot(2,1,2)
sb.barplot(x=probs, y=flowers, color=sb.color_palette()[0]);
plt.show()

#predict("image_06657.jpg")
# Out:
# #################
# torch.Size([1, 3, 224, 224])
# ^^^^^^^^^^^^^^^^^
# [0.51313984 0.16735062 0.09283081 0.06466661 0.06168026]
# ^^^^^^^^^^^^^^^^^
# [10 97 74 43 90]

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
